# %% [markdown]
# # Global Atmospheric Column Model
#
# The tables below give roughly the emissions for the main atmospheric constrituents. They can help you to determine anthropogenic and natural emissions, pre-industrial conditions, and possible future scenarios.
# <table>
#   <caption>Table 1: Emissions of CO expressed in teragram (Tg) per year, 1 Tg = 10$^{12}$ g.
#   NMHC = Non-Methane HydroCarbons</caption>
# <tr>
# <th>Source Category</th>
# <th>CO Emission (Tg/year)</th>
# </tr>
# <tr>
# <td>Energy Use</td>
# <td>540</td>
# </tr>
# <tr>
# <td>Anthropogenic Biomass Burning</td>
# <td>400</td>
# </tr>
# <tr>
# <td>Wildfires</td>
# <td>30</td>
# </tr>
# <tr>
# <td>Vegetation</td>
# <td>100</td>
# </tr>
# <tr>
# <td>Oxidation of natural CH$_4$</td>
# <td>250</td>
# </tr>
# <tr>
# <td>Oxidation of anthropogenic CH$_4$</td>
# <td>595</td>
# </tr>
# <tr>
# <td>Oxidation of natural NMHC</td>
# <td>325</td>
# </tr>
# <tr>
# <td>Oxidation of anthropogenic NMHC</td>
# <td>120</td>
# </tr>
# <tr>
# <td>Oceans</td>
# <td>100</td>
# </tr>
# <tr>
# <td>Total</td>
# <td>2460</td>
# </tr>
# </table>
#
# <table>
#   <caption>Table 2: Emissions of NOx expressed in teragram N (Tg) per year, 1 Tg = 10$^{12}$ g.
#   (from Jacob, 1999)</caption>
# <tr>
# <th>Source Category</th>
# <th>NOx Emission (TgN/year)</th>
# </tr>
# <tr>
# <td>Fossil Fuel Combustion</td>
# <td>21</td>
# </tr>
# <tr>
# <td>Biomass Burning</td>
# <td>12</td>
# </tr>
# <tr>
# <td>Soils</td>
# <td>6</td>
# </tr>
# <tr>
# <td>Lightning (added in column)</td>
# <td>(5)</td>
# </tr>
# <tr>
# <td>Total (Excluding lightning)</td>
# <td>39</td>
# </tr>
# </table>
#
# <table>
#   <caption>Table 3: Emissions of CH$_4$ expressed in teragram CH$_4$ (Tg) per year, 1 Tg = 10$^{12}$ g.
#   </caption>
# <tr>
# <th>Source Category</th>
# <th>CH$_4$ Emission (Tg/year)</th>
# </tr>
# <tr>
# <td>Fossil Fuel Combustion</td>
# <td>120</td>
# </tr>
# <tr>
# <td>Biomass Burning and Biofuel</td>
# <td>35</td>
# </tr>
# <tr>
# <td>Soil</td>
# <td>-25</td>
# </tr>
# <tr>
# <td>Total wetlands</td>
# <td>185</td>
# </tr>
# <tr>
# <td>Agricultural including rice cultivation</td>
# <td>125</td>
# </tr>
# <tr>
# <td>Other natural</td>
# <td>65</td>
# </tr>
# <tr>
# <td>Waste Management</td>
# <td>65</td>
# </tr>
# <tr>
# <td>Total </td>
# <td>570</td>
# </tr>
# </table>
#
# <table>
#   <caption>Table 4: Emissions of NMHC expressed in teragram CO equavalent (Tg) per year, 1 Tg = 10$^{12}$ g.
#   </caption>
# <tr>
# <th>Source Category</th>
# <th>Emission (Tg CO eq./year)</th>
# </tr>
# <tr>
# <td>Fossil Fuel Combustion</td>
# <td>400</td>
# </tr>
# <tr>
# <td>Biomass Burning</td>
# <td>80</td>
# </tr>
# <tr>
# <td>Vegetation</td>
# <td>940</td>
# </tr>
# <tr>
# <td>Total </td>
# <td>1420</td>
# </tr>
# <tr>
# <td>Amount oxidized to CO</td>
# <td>1000</td>
# </tr>
# </table>

# %%
from pylab import *
from model1d import *
from bokeh.io import output_notebook
output_notebook()

xlf = model_1d()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9c0fb920-51f0-45cb-9243-2135e499acb6">Loading BokehJS ...</span>
#     </div>
# Reached steady state in 5848 iterations with a surface methane mixing ratio of   1666.1 ppb
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="606a9a06-bf9e-4d76-b336-5a9cc54d1a24"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
# ...
